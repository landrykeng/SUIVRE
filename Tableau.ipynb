# %%
import pandas as pd 
import numpy as np

# %%
df_rejet=pd.read_excel("Data_collected.xlsx",sheet_name="Rejet")
df_synthese=pd.read_excel("Data_collected.xlsx",sheet_name="Synthese")
df_initial=pd.read_excel("Data_collected.xlsx",sheet_name="Initial")
df_echantillon=pd.read_excel("Echantillon.xlsx")

# %%
df_rejet
# Out:
#      rejets-id  level-1-id  occ  nrejet  Numéro de facture  Numéro de chèque  \
# 0            1           4    1       1           360448.0          504360.0
# 1            1           9    1       1           516048.0          506227.0
# 2            2           9    2       2           686505.0          506224.0
# 3            3           9    3       3           770115.0          506212.0
# 4            4           9    4       4           516048.0          506227.0
# ..         ...         ...  ...     ...                ...               ...
# 402          8           1    8       8              512.0          595512.0
# 403          9           1    9       9              508.0          595508.0
# 404         10           1   10      10              510.0          595510.0
# 405          1           3    1       1              715.0          574715.0
# 406          2           3    2       2              705.0          574705.0
#
# ...

# %%
df_synthese
# Out:
#       level-1-id  occ  Numéro ligne Type de prestation           Prestation  \
# 0              1    1             1       Forfaitaires                 CPN1
# 1              1    2             2       Forfaitaires                 CPN2
# 2              1    3             3       Forfaitaires                 CPN3
# 3              1    4             4       Forfaitaires                 CPN4
# 4              1    5             5       Forfaitaires  Accouchement simple
# ...          ...  ...           ...                ...                  ...
# 1545           4    3             3       Forfaitaires                 CPN1
# 1546           4    4             4       Forfaitaires                 CPN2
# 1547           4    5             5       Forfaitaires                 CPN3
# 1548           4    6             6       Forfaitaires                  109
# 1549           4    7             7       Forfaitaires                CPONN
#
# ...

# %%
df_initial
# Out:
#      level-1-id  Nombre de chèque à saisir  \
# 0             1                        NaN
# 1             2                        NaN
# 2             3                        0.0
# 3             4                        1.0
# 4             1                        0.0
# ..          ...                        ...
# 150           1                       10.0
# 151           1                        0.0
# 152           2                        0.0
# 153           3                        2.0
# 154           4                        0.0
#
#                                                   FOSA     Aire de santé  \
# 0    CS MISSION CHRETIENNE NKOEMVONE               ...     AS NYABESSANG
# 1    CS MISSION CHRETIENNE NKOEMVONE               ...     AS NYABESSANG
# 2    CS MISSION CHRETIENNE NKOEMVONE               ...     AS NYABESSANG
# 3    CS MISSION CHRETIENNE NKOEMVONE               ...     AS NYABESSANG
# 4    HOPITAL REGIONAL EBOLOWA                      ...   AS AMBAM URBAIN
# ...

# %%
df_echantillon
# Out:
#         Code                              FOSA  Région  District
# 0    1010101                        CSI Bandam       1       101
# 1    1010202     Hopital de District de Bankim       1       101
# 2    1010203  Centre de Sante Islamique Bankim       1       101
# 3    1010304                    CSI Kimi-petel       1       101
# 4    1010405             CSP Baptiste Nyamboya       1       101
# ..       ...                               ...     ...       ...
# 115  2124353                          CSI MEBA       2       212
# 116  2124454                CSP EPC NKOUMADJAP       2       212
# 117  2124555                      CSI NGOLBANG       2       212
# 118  2124656  CSP CATHOLIQUE SAINTE MARGUERITE       2       212
# 119  2124657          HÔPITAL DISTRICT ZOETELE       2       212
#
# [120 rows x 4 columns]
